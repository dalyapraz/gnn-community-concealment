# %% [markdown]
# ## Degree distribution check

# %%
from analysis_helper import plot_results_by_p
df_all, figs = plot_results_by_p(
    folder='results_fcomdice',
    file_glob='dmon_*average_community.csv',
    metrics=['ECS'],
    # ylim_per_metric={'ECS': (0, 1.0), 'M1': (-0.005, 0.19), 'M2': (-0.02, 1.05)},
    mu_values=[0.01, 0.1, 0.3, 0.5],  # Only plot these mu values
    # metrics=['M1', 'M2'],
    # ylim_per_metric={'M1': (-0.005, 0.19), 'M2': (-0.02, 1.05)},
    ylim_per_metric={'ECS': (0, 1.0)},
    figsize_colwidth=6,
    metric_markers={'ECS':'x'}
)
# Out:
# /Users/dalyapraz/Desktop/IUPhD/ORNL Community Resilience/gnn-clustering-attack-defense/analysis_helper.py:211: DtypeWarning: Columns (6,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(fp, keep_default_na=False) for fp in csv_files]
# /Users/dalyapraz/Desktop/IUPhD/ORNL Community Resilience/gnn-clustering-attack-defense/analysis_helper.py:211: DtypeWarning: Columns (6,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(fp, keep_default_na=False) for fp in csv_files]
# /Users/dalyapraz/Desktop/IUPhD/ORNL Community Resilience/gnn-clustering-attack-defense/analysis_helper.py:211: DtypeWarning: Columns (6,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = [pd.read_csv(fp, keep_default_na=False) for fp in csv_files]
# ...
